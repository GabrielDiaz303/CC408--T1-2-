# %% [markdown]
# # Ciencia de datos (CC408) - Primavera 2024
#
# ## Trabajo Práctico 1 - Parte 2

# %% [markdown]
# ### Reglas de formato y presentación
# - El trabajo debe estar debidamente documentado comentado (utilizando #) para que tanto los docentes como sus compañeros puedan comprender el código fácilmente.
#
# - El mismo debe ser completado en este Jupyter Notebook y entregado como tal, es decir en un archivo .ipynb

# %% [markdown]
# ### Fecha de entrega:
# Domingo Domingo 8 de septiembre a las 23:59hs

# %% [markdown]
# ### Modalidad de entrega
# - Al finalizar el trabajo práctico deben hacer un último <i>commit</i> en su repositorio de GitHub llamado “Entrega final del tp”.
# - Asegurense de haber creado una carpeta llamada TP1. Este Jupyter Notebook y el correspondiente al TP1 - Parte 2 deben estar dentro de esa carpeta.
# - También deben enviar el link de su repositorio -para que pueda ser clonado y corregido- al siguiente email: ispiousas@udesa.edu.ar
# - La última versión en el repositorio es la que será evaluada. Por lo que es importante que:
#     - No envien el correo hasta no haber terminado y estar seguros de que han hecho el <i>commit y push</i> a la versión final que quieren entregar. Debido a que se pueden tomar hasta 3 días de extensión a lo largo del curso, no se corregirán sus tareas hasta no recibir el correo.
#     - No hagan nuevos <i>push</i> despues de haber entregado su versión final. Esto generaría confusión acerca de que versión es la que quieren que se les corrija.

# %% [markdown]
# ### Parte A

# %% [markdown]
# #### Ejercicio 1
# Usando la API de Mercado Libre, obtener los ítems de una consulta de búsqueda. Pueden buscar cualquier producto de su interés.

# %%
# Resolver acá
import requests
buscar = "set de legos"
url = "https://api.mercadolibre.com/sites/{}/search?q={}".format("MLA", buscar.replace(" ", "%20"))

# Hacemos el pedido o request y obtenemos la response
response = requests.request("GET", url)
print(response) # correcto

# Vemos el texto
response.text
# Out:
# <Response [200]>
# '{"site_id":"MLA","country_default_time_zone":"GMT-03:00","query":"set de legos","paging":{"total":293,"primary_results":293,"offset":0,"limit":50},"results":[{"id":"MLA1737589104","title":"Lego® Minecraft - La Aventura En El Pantano (21240) Cantidad De Piezas 65","condition":"new","thumbnail_id":"641883-MLU72493433316_102023","catalog_product_id":"MLA24525438","listing_type_id":"gold_special","sanitized_title":"lego-minecraft-la-aventura-en-el-pantano-21240-cantidad-de-piezas-65","permalink":"https://www.mercadolibre.com.ar/lego-minecraft-la-aventura-en-el-pantano-21240-cantidad-de-piezas-65/p/MLA24525438#wid=MLA1737589104&sid=unknown","buying_mode":"buy_it_now","site_id":"MLA","category_id":"MLA1157","domain_id":"MLA-TOY_BUILDING_SETS","thumbnail":"http://http2.mlstatic.com/D_641883-MLU72493433316_102023-I.jpg","currency_id":"ARS","order_backend":1,"price":39490,"original_price":null,"sale_price":{"price_id":"","amount":39490,"conditions":{"eligible":true,"context_restrictions":[],"start_time":null,"end_time":null},"currency_id":"ARS","exchange_rate":null,"payment_method_prices":[],"payment_method_type":"TMP","regular_amount":null,"type":"standard","metadata":{}},"available_quantity":1,"official_store_id":null,"use_thumbnail_id":true,"accepts_mercadopago":true,"shipping":{"store_pick_up":false,"free_shipping":true,"logistic_type":"xd_drop_off","mode":"me2","tags":["self_service_in","mandatory_free_shipping"],"benefits":null,"promise":null,"shipping_score":-1},"stop_time":"2044-09-01T18:21:16.000Z","seller":{"id":1091538840,"nickname":"BARBIESTOREOK"},"attributes":[{"id":"BRAND","name":"Marca","value_id":"1249447","value_name":"Lego","attribute_group_id":"OTHERS","attribute_group_name":"Otros","value_struct":null,"values":[{"id":"1249447","name":"Lego","struct":null,"source":1}],"source":1,"value_type":"string"},{"id":"DETAILED_MODEL","name":"Modelo detallado","value_id":"38801863","value_name":"Kit De Construção Minecraft 21240 A Aventura No Pântano Com 65 Peças Lego","attribute_group_id":"OTHERS","attribute_group_name":"Otros","value_struct":null,"values":[{"id":"38801863","name":"Kit De Construção Minecraft 21240 A Aventura No Pântano Com 65 Peças Lego","struct":null,"source":1}],"source":1,"value_type":"string"},{"id":"GTIN","name":"Código universal de producto","value_id":null,"value_name":"673419374767","attribute_group_id":"OTHERS","attribute_group_name":"Otros","value_struct":null,"values":[{"id":null,"name":"673419374767","struct":null,"source":1}],"source":1,"value_type":"string"},{"id":"ITEM_CONDITION","name":"Condición del ítem","value_id":"2230284","value_name":"Nuevo","attribute_group_id":"OTHERS","attribute_group_name":"Otros","value_struct":null,"values":[{"id":"2230284","name":"Nuevo","struct":null,"source":6402814585011704}],"source":6402814585011704,"value_type":"list"},{"id":"LENGTH","name":"Largo","value_id":"7818553","value_name":"8 cm","attribute_group_id":"OTHERS","attribute_group_name":"Otros","value_struct":{"number":8,"unit":"cm"},"values":[{"id":"7818553","name":"8 cm","struct":{"number":8,"unit":"cm"},"source":1}],"source":1,"value_type":"number_unit"},{"id":"LINE","name":"Línea","value_id":"9854394","value_name":"Minecraft","attribute_group_id":"OTHERS","attribute_group_name":"Otros","value_struct":null,"values":[{"id":"9854394","name":"Minecraft","struct":null,"source":1}],"source":1,"value_type":"string"},{"id":"MODEL","name":"Modelo","value_id":"18971622","value_name":"21240","attribute_group_id":"OTHERS","attribute_group_name":"Otros","value_struct":null,"values":[{"id":"18971622","name":"21240","struct":null,"source":1}],"source":1,"value_type":"string"},{"id":"RECOMMENDED_AGE_GROUP","name":"Edad recomendada","value_id":"28417227","value_name":"5-7 años","attribute_group_id":"OTHERS","attribute_group_name":"Otros","value_struct":null,"values":[{"id":"28417227","name":"5-7 años","struct":null,"source":1}],"source":1,"value_type":"list"},{"id":"WEIGHT","name":"Peso","value_id":"1457","value_na ...

# %% [markdown]
# #### Ejercicio 2
# Guarden los precios de los ítems obtenidos en un dataframe y calculen el precio promedio, el mínimo y el máximo.

# %%
# Resolver acá

datos=response.json()
#print(datos["results"][0]["price"])

precios=[] #creamos una lista vacia
for i in range(len(datos["results"])):
    precios.append(datos["results"][i]["price"]) #con el append vamos agregando al final de la lista cada uno de los precios y los acomoda 

promedio=sum(precios)/len(precios)
promedio

minimo=min(precios)
minimo

maximo=max(precios)
maximo
# Out:
# 764999.99

# %% [markdown]
# #### Ejercicio 3
# Armen un histograma de los precios. ¿Ven algún <i>outlier<i>?
# Nota: pueden usar la librería de Matplotlib o la de Pandas.

# %%
# Resolver acá
import pandas as pd

pd.hist(precios)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[78], line 4
#       1 # Resolver acá
#       2 import pandas as pd
# ----> 4 pd.hist(precios)
#
# AttributeError: module 'pandas' has no attribute 'hist'

# %% [markdown]
# #### Ejercicio 4
# Realicen alguna consulta adicional utilizando la API de Mercado Libre (debe ser alguna consulta que no se haya visto en clase. Por ejemplo, obtener los ítems de un vendedor en particular, obtener los productos de una categoría u otros). Analicen los resultados y comenten uno o dos que les parezcan interesantes (por ejemplo, precios promedio de los productos de un vendedor, diferencia entre el precio original y actual, si acepta mercado pago para la compra de productos, etc.)

# %%
# Resolver acá

# %% [markdown]
# ### Parte B

# %% [markdown]
# #### Ejercicio 5
# De la página de noticias del [diario La Nación](https://www.lanacion.com.ar/), utilicen herramientas de web scraping para obtener los links de las noticias de la portada. Guarden los links obtenidos en un dataframe y expórtenlo a un archivo de excel.
#
# Nota 1: es posible que logren obtener los links a las noticias sin el dominio: "https://www.lanacion.com.ar/". De ser así, concatenen el dominio a la ruta del link obtenido, tal que se obtenga un link al que se pueda acceder. Es decir, que las cadenas de caracteres finales tendrán la forma: https://www.lanacion.com.ar/*texto_obtenido*)
#
# Nota 2: junto con su entrega, adjunten una captura de la página de noticias al momento de correr su código. Eso servirá al momento de la corrección para verificar que los links obtenidos hacen referencia a las noticias de ese día y hora.

# %%
# Resolver acá
